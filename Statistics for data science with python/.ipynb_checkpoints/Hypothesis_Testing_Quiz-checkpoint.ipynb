# %% [markdown]
# # Hypothesis Testing Quiz

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as st
import math

# %% [markdown]
# ## Import Data

# %%
ratings_url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ST0151EN-SkillsNetwork/labs/teachingratings.csv'
ratings_df = pd.read_csv(ratings_url)
ratings_df.head()
# Out:
#   minority  age  gender credits    beauty  eval division native tenure  \
# 0      yes   36  female    more  0.289916   4.3    upper    yes    yes
# 1      yes   36  female    more  0.289916   3.7    upper    yes    yes
# 2      yes   36  female    more  0.289916   3.6    upper    yes    yes
# 3      yes   36  female    more  0.289916   4.4    upper    yes    yes
# 4       no   59    male    more -0.737732   4.5    upper    yes    yes
#
#    students  allstudents  prof  PrimaryLast  vismin  female  single_credit  \
# 0        24           43     1            0       1       1              0
# 1        86          125     1            0       1       1              0
# 2        76          125     1            0       1       1              0
# 3        77          123     1            1       1       1              0
# 4        17           20     2            0       0       0              0
#
#    upper_division  English_speaker  tenured_prof
# ...

# %%
ratings_df.shape
# Out:
# (463, 19)

# %% [markdown]
# ## Question 1
# ![image.png](attachment:750bf350-54a3-4706-a3ed-38f314e32bc1.png)

# %%
cont_table = pd.crosstab(ratings_df['credits'], ratings_df['native'])
cont_table
# Out:
# native   no  yes
# credits
# more     27  409
# single    1   26

# %% [markdown]
# Both variables are categorial variables. So we're gonna perform Chi-square test

# %% [markdown]
# ## Question 2
# ![image.png](attachment:f14743a4-d0a3-4644-b45e-8d3ea5234a39.png)

# %%
cont_table2 = pd.crosstab(ratings_df['tenure'], ratings_df['gender'])
cont_table2
# Out:
# gender  female  male
# tenure
# no          50    52
# yes        145   216

# %%
scipy.stats.chi2_contingency(cont_table2) #degree of freedom = 1
# Out:
# (2.20678166999886,
#  0.1374050603563787,
#  1,
#  array([[ 42.95896328,  59.04103672],
#         [152.04103672, 208.95896328]]))

# %% [markdown]
# ## Question 3
# ![image.png](attachment:9ee41076-d079-450f-8bf4-684686795a19.png)

# %%
(91.54 - 63.18)/13.27
# Out:
# 2.1371514694800307

# %% [markdown]
# ## Question 4
# ![image.png](attachment:10d8cc76-b664-4fc0-96f1-f20384eba4c1.png)

# %% [markdown]
# We use ANOVA because there's more than two groups of samples for comparing the means

# %% [markdown]
# ## Question 5
# ![image.png](attachment:10f54a66-f81b-4dcf-9adc-b3dc7e9e4243.png)

# %% [markdown]
# We use z-test because we're comparing the sample mean with population mean

# %% [markdown]
# ## Question 6
# ![image.png](attachment:aa613469-c450-4ca3-a8dc-b067025dc0b8.png)

# %%
1 - st.norm.cdf((500-490)/math.sqrt(400)) #probability greater than
# Out:
# 0.3085375387259869

# %% [markdown]
# ## Question 7
# ![image.png](attachment:a445c139-6300-4588-af7c-edbbfe7da4b6.png)

# %% [markdown]
# P-values are proportion and range from 0 to 1. The left-tail test for this will also be 0.042

# %% [markdown]
# ## Question 8
# ![image.png](attachment:d4540b25-9ce8-4d57-8bbf-3cd147226392.png)

# %%
((st.norm.ppf(0.25))*20) + 90
# Out:
# 76.51020499607837

# %% [markdown]
# ## Question 9
# ![image.png](attachment:a6320966-5734-46a1-990f-4dfb55c7d21f.png)

# %% [markdown]
# P-value obtained is greater than alpha. Therrefore we fail to reject the null hypothesis given that we don't have enough evidence to prove alternative hypothesis

# %% [markdown]
# ## Question 10
# ![image.png](attachment:7033cc5b-31ac-4fd9-a4b6-e71bad83151c.png)

# %%
1 - st.norm.cdf((6.9 - 5.85)/0.35) #probability greater than
# Out:
# 0.0013498980316301035
